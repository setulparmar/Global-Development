# %% [markdown]
# # Global Development
#
# In this project, we have shown the development of countries or sub-continents across time (till 2013). I used the dataset “global_development.csv”, which we got from the “CORGIS Datasets Project”.

# %% [markdown]
# ## 1. Downloading and Uploading the dataset

# %% [markdown]
# Link: https://corgis-edu.github.io/corgis/datasets/csv/global_development/global_development.csv
#
# Note: We have changed the column names just for our convenience.

# %% [markdown]
# ## 2. Data Preparation and Cleaning

# %%
# Importing necessary libraries

import pandas as pd
import numpy as np

# %%
# Uploading dataset in Google Collab

from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-554d7401-8d77-4220-afae-b0429af82fd4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-554d7401-8d77-4220-afae-b0429af82fd4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving global_development.csv to global_development.csv

# %%
import io
global_development = pd.read_csv(io.BytesIO(data_to_load['global_development.csv']))

# %%
global_development.head(10)
# Out:
#   Country  Year  ...  urban_population_percent  urban_population_percent_growth
# 0  Canada  1980  ...                    75.623                         1.050578
# 1  Canada  1981  ...                    75.663                         1.346126
# 2  Canada  1982  ...                    75.712                         1.305333
# 3  Canada  1983  ...                    75.874                         1.419293
# 4  Canada  1984  ...                    76.035                         1.214785
# 5  Canada  1985  ...                    76.195                         1.171941
# 6  Canada  1986  ...                    76.354                         1.137905
# 7  Canada  1987  ...                    76.502                         1.198524
# 8  Canada  1988  ...                    76.522                         1.337908
# 9  Canada  1989  ...                    76.542                         1.317198
#
# [10 rows x 25 columns]

# %%
global_development.info()     # returns datatype of all the available columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6426 entries, 0 to 6425
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Country                                 6426 non-null   object
#  1   Year                                    6426 non-null   int64
#  2   birth_rate                              6426 non-null   float64
#  3   death_rate                              6426 non-null   float64
#  4   fertility_rate                          6426 non-null   float64
#  5   life_expectancy_birth_female            6426 non-null   float64
#  6   life_expectancy_birth_male              6426 non-null   float64
#  7   life_expectancy_birth_total             6426 non-null   float64
#  8   population_growth                       6426 non-null   float64
#  9   total_population                        6426 non-null   float64
# ...

# %%
global_development.describe()     # returns the description of all the columns
# Out:
#               Year  ...  urban_population_percent_growth
# count  6426.000000  ...                      6426.000000
# mean   1995.018519  ...                         2.938491
# std      11.122234  ...                         2.204711
# min    1960.000000  ...                        -7.102666
# 25%    1987.000000  ...                         1.346809
# 50%    1995.000000  ...                         2.840338
# 75%    2004.000000  ...                         4.132614
# max    2013.000000  ...                        48.938941
#
# [8 rows x 24 columns]

# %%
global_development.columns      # returns all the available columns
# Out:
# Index(['Country', 'Year', 'birth_rate', 'death_rate', 'fertility_rate',
#        'life_expectancy_birth_female', 'life_expectancy_birth_male',
#        'life_expectancy_birth_total', 'population_growth', 'total_population',
#        'mobile_cellular_subscriptions',
#        'mobile_cellular_subscriptions_per_100', 'telephone_lines',
#        'telephone_lines_per_100', 'rural_agricultural_land',
#        'rural_agricultural_land_percent', 'rural_agricultural_arable_land',
#        'rural_agricultural_arable_land_percent', 'rural_land_area',
#        'rural_population', 'rural_population_growth', 'rural_surface_area',
#        'urban_population_density', 'urban_population_percent',
#        'urban_population_percent_growth'],
#       dtype='object')

# %%
global_development.shape
# Out:
# (6426, 25)

# %%
global_development.isnull().sum().sum()       # returns total number of null values all over the dataset
# Out:
# 0

# %% [markdown]
# As, the total number of null values all over the dataset is 0, hence there is no need for handling the null values and preprocessing

# %% [markdown]
# ## 3. Data Analysis and Visualization

# %%
total_world_population = global_development[global_development.Year == 2013].total_population.sum()

# %%
print("The total world population is: ", total_world_population, "(till 2013)")
# Out:
# The total world population is:  44135531345.0 (till 2013)

# %%
# Importing Data visualization Libraries

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
sns.set_style("darkgrid")

# %% [markdown]
# ### 1. Who have greater life expectancy: male/female?

# %%
plt.figure(figsize=(12, 6))
plt.title('Comparison of life expectancy of male and female over time')

sns.scatterplot('life_expectancy_birth_male', 'life_expectancy_birth_female', hue='Year', data=global_development);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# This scatter plot shows us an interesting facts that:
# 1. The life expectancy of both male and female are almost same or constant.
# 2. The majority of people are having their life in the range of 50 to 65.
# 3. As the time is increasing, the life expectancy of both male and females are increasing.

# %% [markdown]
# ### 2. How the number of cellular subcriptions increased in whole world over years?

# %%
plt.figure(figsize = (20,10))
plt.bar(global_development.Year, global_development.mobile_cellular_subscriptions_per_100);

# %% [markdown]
# As per our data and its bar visualization, firstly when the telephone (wired) was discovered, the no. of its connections also increased till 1980s.
#
# But when the cellular telephones came the wired connections decreased till 1990s and then started to increase rapidly with time all over the world.

# %% [markdown]
# ### 3. How the rural population percent are changing with urban population percent over time?

# %%
plt.figure(figsize = (20,10))
sns.lineplot(global_development.Year, global_development.urban_population_percent_growth)
sns.lineplot(global_development.Year,global_development.rural_population_growth)
plt.xlabel('Year')
plt.ylabel('Population Growth')
plt.title("Increase in Population")
plt.legend(['Urban', 'Rural']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# From the above line plot for the rural and urban population growth, we got to know that the majority of countries have resulted in the increase in the population growth above of that of rural population, and hence shows the urbanization over time.
# From 1960 to 1980, the population growth for both urban and rural was almost constant, but after 1980s the urban population growth drastically increased and rural decreased for most of the countries.

# %% [markdown]
# ### 4. Find how the agricultural land percent is changing year by year in India?

# %%
plt.figure(figsize = (20,10))
plt.plot(global_development[global_development.Country == "India"].Year, global_development[global_development.Country == "India"].rural_agricultural_land_percent)
plt.xlabel('Year')
plt.ylabel('Agriculture Land Percent')
plt.title("Change in the agricultural land");

# %% [markdown]
# From the above plotting, we got to know that as we are advancing towards the development the engagement in the agricultural activities is decreasing, which is the threat to our nation.
# So, we need to focus on the agricultural advancement and profits to the farmers so that agricultural activities do not stop.

# %% [markdown]
# ### 5. Which year is having the highest birth rate ?

# %%
plt.figure(figsize = (20,10))
plt.xticks(rotation = 'vertical')
sns.barplot("Year", "birth_rate", data = global_development);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# From the above graph, we got to know that the average growth rate all over the world is decreasing year by year.
# Therefore, the highest growth rate as per our data was at the year period: 1961 to 1965.

# %% [markdown]
# ### 6. Compare the trend of the density of cellular subscriptions and telephone lines over the passing years.

# %%
plt.figure(figsize = (12,6))
plt.plot(global_development[global_development.Country == "India"].Year, global_development[global_development.Country == "India"].mobile_cellular_subscriptions_per_100)
plt.plot(global_development[global_development.Country == "India"].Year, global_development[global_development.Country == "India"].telephone_lines_per_100)
plt.legend(['Mobile', 'Telephone'])
plt.xlabel("Years")
plt.ylabel("Density of Subscriptions");

# %% [markdown]
# From the above graph we can infer that, in India the telephone subscriptions introduced during 1980s. and then showed a steady growth year by year till 2005.
# And then the subscriptions density started decreasing.
# For the mobile subscriptions, it became available during 2000 to 2003, and then showed a rapid growth till 2010.
# Notice that when the mobile subscriptions gained popularity, the telephone subscriptions started decreasing.

# %% [markdown]
# # 7.Finding correlation among features using heatmap

# %%
import seaborn as sns
corrs = global_development.select_dtypes(include=np.number).corr(method = 'kendall')

# plot clustered heatmap of correlations
sns.clustermap(corrs, cbar_pos=(-0.05, 0.8, 0.05, 0.18), cmap='seismic', center=0);

# %% [markdown]
# # 8. Boxplot between features

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x="Year", y='birth_rate', data=global_development);

# %% [markdown]
# # 9.Birth Rate vs Death Rate

# %%
#birth rate vs death rate
#we use the birth_rate<200 to reomve the outlier.
sns.lmplot(x='birth_rate',y='death_rate',data=global_development[global_development['birth_rate'] < 20])

# %% [markdown]
# ## Dimensionality Reduction
#
# We will classify our result on the basis of the $urban\_growth\_population$ variable, as it roughly indicates the urbanization rate.
#
# **Criteria of target variable:** If the rate of urban population growth is greater than 2, then it is considered to be of class 1 (urbanized), else of class 0 (still rural).

# %% [markdown]
# ### 1. PCA using Logistic Regression

# %%
X = global_development.iloc[:, 1:24].values
y = global_development.iloc[:, 24].values

# %%
y
y1 = []
for i in y:
  if i < 2:
    i = 0
  else:
    i = 1
  y1.append(i)
y = y1

# %%
np.unique(y)
# Out:
# array([0, 1])

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Feature Scaling
# Doing the pre-processing part on training and testing set such as fitting the Standard scale.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
  
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Applying the PCA function into training and testing set for analysis.

# %%
from sklearn.decomposition import PCA
  
pca = PCA(n_components = 2)
  
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)
  
explained_variance = pca.explained_variance_ratio_

# %% [markdown]
# ## Fitting Logistic Regression To the training set

# %%
from sklearn.linear_model import LogisticRegression  
from sklearn import linear_model

classifiers = [linear_model.LinearRegression()]
for item in classifiers:
    #print(item)
    clf = item
    clf.fit(X_train, y_train)
    #print(clf.predict(predictionData),'\n')

# %% [markdown]
# ## Predicting the test set result

# %%
y_pred = clf.predict(X_test)
y1 = []
for i in y_pred:
  if i < 0.5:
    i = 0
  else:
    i = 1
  y1.append(i)
y_pred = y1

# %% [markdown]
# ## Making the confusion matrix

# %%
from sklearn.metrics import confusion_matrix
  
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[359  94]
#  [141 692]]

# %% [markdown]
# ##  Predicting the training set result

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.79      0.75       453
#            1       0.88      0.83      0.85       833
#
#     accuracy                           0.82      1286
#    macro avg       0.80      0.81      0.80      1286
# weighted avg       0.82      0.82      0.82      1286

# %%
from matplotlib.colors import ListedColormap

X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1,
                     stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1,
                     stop = X_set[:, 1].max() + 1, step = 0.01))
  
plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(),
             X2.ravel()]).T).reshape(X1.shape), alpha = 0.75,
             cmap = ListedColormap(('yellow', 'white', 'aquamarine')))
  
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
  
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1])
  
plt.title('PCA using Logistic Regression (Training set)')
plt.xlabel('PC1') # for Xlabel
plt.ylabel('PC2') # for Ylabel
plt.legend() # to show legend
  
# show scatter plot
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from matplotlib.colors import ListedColormap
  
X_set, y_set = X_test, y_test
  
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1,
                     stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1,
                     stop = X_set[:, 1].max() + 1, step = 0.01))
  
plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(),
             X2.ravel()]).T).reshape(X1.shape), alpha = 0.75,
             cmap = ListedColormap(('yellow', 'white', 'aquamarine'))) 
  
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
  
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                 label = j)
  
# title for scatter plot
plt.title('PCA using Logistic Regression (Test set)') 
plt.xlabel('PC1') # for Xlabel
plt.ylabel('PC2') # for Ylabel
plt.legend()
  
# show scatter plot
plt.show()

# %% [markdown]
# # Covariance
# Covariance of a matrix A is A*AT

# %%
covariance=np.cov(X)
print(covariance)
# Out:
# [[3.38710883e+13 3.43155143e+13 3.47285445e+13 ... 6.63349703e+14
#   6.74350423e+14 6.87006627e+14]
#  [3.43155143e+13 3.47702402e+13 3.51923550e+13 ... 6.71679923e+14
#   6.82828233e+14 6.95646721e+14]
#  [3.47285445e+13 3.51923550e+13 3.56225435e+13 ... 6.79861015e+14
#   6.91161012e+14 7.04144976e+14]
#  ...
#  [6.63349703e+14 6.71679923e+14 6.79861015e+14 ... 2.46883304e+16
#   2.57321389e+16 2.67031584e+16]
#  [6.74350423e+14 6.82828233e+14 6.91161012e+14 ... 2.57321389e+16
#   2.69315599e+16 2.80332885e+16]
#  [6.87006627e+14 6.95646721e+14 7.04144976e+14 ... 2.67031584e+16
#   2.80332885e+16 2.92453406e+16]]

# %% [markdown]
# # SVD
#
# The function takes a matrix and returns the U, Sigma and V^T elements. The Sigma diagonal matrix is returned as a vector of singular values. The V matrix is returned in a transposed form

# %%
from numpy import array
from scipy.linalg import svd
# define a matrix
A = X
print(A)
# SVD
U, s, VT = svd(A)
print('U\n\n\n',U)
print('\ns\n\n\n',s)
print('\nVT\n\n\n',VT)
# Out:
# [[1.98000000e+03 1.54000000e+01 7.00000000e+00 ... 9.98467000e+06
#   2.66970620e+00 7.56230000e+01]
#  [1.98100000e+03 1.54000000e+01 7.10000000e+00 ... 9.98467000e+06
#   2.70445626e+00 7.56630000e+01]
#  [1.98200000e+03 1.53000000e+01 7.00000000e+00 ... 9.98467000e+06
#   2.73821660e+00 7.57120000e+01]
#  ...
#  [2.01100000e+03 3.88072927e+01 1.09367736e+01 ... 2.03921710e+07
#   3.14824005e+01 3.22495059e+01]
#  [2.01200000e+03 3.83661400e+01 1.06610187e+01 ... 1.97657185e+07
#   3.23368404e+01 3.26845031e+01]
#  [2.01300000e+03 3.79246978e+01 1.04079429e+01 ... 1.97671535e+07
#   3.32069069e+01 3.31251611e+01]]
# U
#
#
#  [[-3.69298802e-04 -1.25843449e-04 -1.96214519e-03 ... -1.14555501e-02
#   -1.01796842e-02 -1.02014820e-02]
#  [-3.74338388e-04 -1.24691259e-04 -2.01814335e-03 ...  1.14945602e-02
#    1.19606215e-02  1.14900435e-02]
#  [-3.79133169e-04 -1.24102823e-04 -2.06581644e-03 ...  5.25997518e-03
#    7.49257383e-03  7.98810044e-03]
#  ...
# ...

# %% [markdown]
# # Eigenvalues and Eigenvectors of the covariance matrix

# %%
import scipy.linalg as la
results = la.eig(covariance)

# %% [markdown]
# The Eigenvalues are

# %%
print(results[0])
# Out:
# [ 1.78142721e+20+0.00000000e+00j  1.32367820e+19+0.00000000e+00j
#   1.62296356e+18+0.00000000e+00j ...  8.70342303e-07+5.52949552e-07j
#   8.70342303e-07-5.52949552e-07j -2.28375136e-07+0.00000000e+00j]

# %% [markdown]
# The Eigenvectors are

# %%
print(results[1])
# Out:
# [[-3.46530805e-04+0.00000000e+00j  1.66079077e-04+0.00000000e+00j
#    1.91790388e-03+0.00000000e+00j ...  2.12935601e-07+2.27777732e-08j
#    2.12935601e-07-2.27777732e-08j -3.47523290e-07+0.00000000e+00j]
#  [-3.51316969e-04+0.00000000e+00j  1.65297412e-04+0.00000000e+00j
#    1.97367832e-03+0.00000000e+00j ...  8.70804411e-09+1.98951740e-08j
#    8.70804411e-09-1.98951740e-08j  7.25908612e-09+0.00000000e+00j]
#  [-3.55926834e-04+0.00000000e+00j  1.64971306e-04+0.00000000e+00j
#    2.02121489e-03+0.00000000e+00j ... -1.26612919e-07-1.54938413e-07j
#   -1.26612919e-07+1.54938413e-07j -3.10205380e-07+0.00000000e+00j]
#  ...
#  [-1.16101141e-02+0.00000000e+00j -3.56711262e-03+0.00000000e+00j
#   -1.74442606e-02+0.00000000e+00j ... -6.54705055e-07+6.62324867e-07j
#   -6.54705055e-07-6.62324867e-07j -1.58393450e-06+0.00000000e+00j]
#  [-1.20138078e-02+0.00000000e+00j -6.54066935e-03+0.00000000e+00j
#   -1.98588319e-02+0.00000000e+00j ...  2.08921693e-06+7.48083919e-06j
# ...

# %% [markdown]
# ### 2. LDA using Random Classifier

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(max_depth=2, random_state=0)

classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[373  80]
#  [162 671]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.82      0.76       453
#            1       0.89      0.81      0.85       833
#
#     accuracy                           0.81      1286
#    macro avg       0.80      0.81      0.80      1286
# weighted avg       0.82      0.81      0.81      1286

# %% [markdown]
# # Students t-test

# %%
from math import sqrt
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from scipy.stats import sem
from scipy.stats import t

data1 = global_development['birth_rate']

data2 = global_development['death_rate']

# function for calculating the t-test for two dependent samples
def dependent_ttest(data1, data2, alpha):
	# calculate means
	mean1, mean2 = mean(data1), mean(data2)
	# number of paired samples
	n = len(data1)
	# sum squared difference between observations
	d1 = sum([(data1[i]-data2[i])**2 for i in range(n)])
	# sum difference between observations
	d2 = sum([data1[i]-data2[i] for i in range(n)])
	# standard deviation of the difference between means
	sd = sqrt((d1 - (d2**2 / n)) / (n - 1))
	# standard error of the difference between the means
	sed = sd / sqrt(n)
	# calculate the t statistic
	t_stat = (mean1 - mean2) / sed
	# degrees of freedom
	df = n - 1
	# calculate the critical value
	cv = t.ppf(1.0 - alpha, df)
	# calculate the p-value
	p = (1.0 - t.cdf(abs(t_stat), df)) * 2.0
	# return everything
	return t_stat, df, cv, p

# calculate the t test
alpha = 0.05
t_stat, df, cv, p = dependent_ttest(data1, data2, alpha)
print('t=%.3f, df=%d, cv=%.3f, p=%.3f' % (t_stat, df, cv, p))
# interpret via critical value
if abs(t_stat) <= cv:
	print('Accept null hypothesis that the means are equal.')
else:
	print('Reject the null hypothesis that the means are equal.')
# interpret via p-value
if p > alpha:
	print('Accept null hypothesis that the means are equal.')
else:
	print('Reject the null hypothesis that the means are equal.')
# Out:
# t=148.172, df=6425, cv=1.645, p=0.000
# Reject the null hypothesis that the means are equal.
# Reject the null hypothesis that the means are equal.

# %% [markdown]
# # Decision Trees and Cross-Validation

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
import numpy as np
import matplotlib.pyplot as plt

# function for fitting trees of various depths on the training data using cross-validation
def run_cross_validation_on_trees(X, y, tree_depths, cv=10, scoring='accuracy'):
    cv_scores_list = []
    cv_scores_std = []
    cv_scores_mean = []
    accuracy_scores = []
    for depth in tree_depths:
        tree_model = DecisionTreeClassifier(max_depth=depth)
        cv_scores = cross_val_score(tree_model, X, y, cv=cv, scoring=scoring)
        cv_scores_list.append(cv_scores)
        cv_scores_mean.append(cv_scores.mean())
        cv_scores_std.append(cv_scores.std())
        accuracy_scores.append(tree_model.fit(X, y).score(X, y))
    cv_scores_mean = np.array(cv_scores_mean)
    cv_scores_std = np.array(cv_scores_std)
    accuracy_scores = np.array(accuracy_scores)
    return cv_scores_mean, cv_scores_std, accuracy_scores
  
# function for plotting cross-validation results
def plot_cross_validation_on_trees(depths, cv_scores_mean, cv_scores_std, accuracy_scores, title):
    fig, ax = plt.subplots(1,1, figsize=(15,5))
    ax.plot(depths, cv_scores_mean, '-o', label='mean cross-validation accuracy', alpha=0.9)
    ax.fill_between(depths, cv_scores_mean-2*cv_scores_std, cv_scores_mean+2*cv_scores_std, alpha=0.2)
    ylim = plt.ylim()
    ax.plot(depths, accuracy_scores, '-*', label='train accuracy', alpha=0.9)
    ax.set_title(title, fontsize=16)
    ax.set_xlabel('Tree depth', fontsize=14)
    ax.set_ylabel('Accuracy', fontsize=14)
    ax.set_ylim(ylim)
    ax.set_xticks(depths)
    ax.legend()

# fitting trees of depth 1 to 24
sm_tree_depths = range(1,25)
sm_cv_scores_mean, sm_cv_scores_std, sm_accuracy_scores = run_cross_validation_on_trees(X_train, y_train, sm_tree_depths)

# plotting accuracy
plot_cross_validation_on_trees(sm_tree_depths, sm_cv_scores_mean, sm_cv_scores_std, sm_accuracy_scores, 
                               'Accuracy per decision tree depth on training data')

# %%
idx_max = sm_cv_scores_mean.argmax()
sm_best_tree_depth = sm_tree_depths[idx_max]
sm_best_tree_cv_score = sm_cv_scores_mean[idx_max]
sm_best_tree_cv_score_std = sm_cv_scores_std[idx_max]
print('The depth-{} tree achieves the best mean cross-validation accuracy {} +/- {}% on training dataset'.format(
      sm_best_tree_depth, round(sm_best_tree_cv_score*100,5), round(sm_best_tree_cv_score_std*100, 5)))
# Out:
# The depth-3 tree achieves the best mean cross-validation accuracy 83.03502 +/- 1.72878% on training dataset

# %%
# function for training and evaluating a tree
def run_single_tree(X_train, y_train, X_test, y_test, depth):
    model = DecisionTreeClassifier(max_depth=depth).fit(X_train, y_train)
    accuracy_train = model.score(X_train, y_train)
    accuracy_test = model.score(X_test, y_test)
    print('Single tree depth: ', depth)
    print('Accuracy, Training Set: ', round(accuracy_train*100,5), '%')
    print('Accuracy, Test Set: ', round(accuracy_test*100,5), '%')
    return accuracy_train, accuracy_test
  

# train and evaluate a 5-depth tree
sm_best_tree_accuracy_train, sm_best_tree_accuracy_test = run_single_tree(X_train, y_train, 
                                                                          X_test, y_test, 
                                                                          sm_best_tree_depth)
# Out:
# Single tree depth:  3
# Accuracy, Training Set:  83.1323 %
# Accuracy, Test Set:  81.25972 %
